# %% [markdown]
# # 02 Data Cleaning and Feature Engineering
#
# Use `src.data.clean_data` and `src.features.build_features` to create transaction-level price features and product-store-week modeling features.
